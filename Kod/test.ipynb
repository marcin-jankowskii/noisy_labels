# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image_path = '/home/cal314-1/Vident-real-smtx/train/3fc66c96-e402-4e24-9e61-227be00c1d6c/mask/00001.png'
image = Image.open(image_path)

# Convert the image to a numpy array
image_array = np.array(image)

# Display the image
plt.imshow(image_array)
#plt.colorbar()
#plt.title("Mask Image")
plt.axis('off')
plt.show()


unique_values = np.unique(image_array)
print("Unique values (classes) in the mask:", unique_values)
# Out:
# Unique values (classes) in the mask: [ 0  1  2  3  5  6  7 10]
